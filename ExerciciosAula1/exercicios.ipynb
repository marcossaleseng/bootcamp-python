# %% [markdown]
# # Estrutura para exercícios de python Leonardo Galvão

# %% [markdown]
# Lembrando que para criar um ambiente virtual utilizando o venv
# Precisamos de executar o comando
#
# ```bash
# python -m venv <nome_do_ambiente>
# ```
# para abrir o ambiente basta
# ```bash
# source <nome_do_ambiente>/Scripts/active
# ```
# E "shazam" já estará em um ambiente fechado

# %% [markdown]
# **Exercício 01**
#
# Crie programa que o usuário digita o seu nome e retorna o número de caracteres

# %%
#%%writefile exercicio1.py
# solução, sem tratamento de erros

# o str antes já prevê espaços
nome = str(input("Digite seu nome: "))
print(f"Seu nome tem {len(nome)} caracteres")

# resultado esperado
#Digite o seu nome: Luciano
#7
# Out:
# Seu nome tem 7 caracteres

# %% [markdown]
# **Exercício 02**
#
# Criar um programa onde o usuário digite dois valores e apareça a soma
#
# Resultado esperado
#
# ```python
# Digite um valor: 7
# Digite outro valor: 10
# 17
# ```

# %%
valor1 = float(input("Digite um valor: "))
valor2 = float(input("Digite outro valor: "))

print(f"A soma dos valores é {valor1 + valor2}")
# Out:
# A soma dos valores é 17.0

# %% [markdown]
# Exercício 03: Refatore o exercício 02 atribuindo variáveis
#
# Já tinha usado variáveis, então pula

# %% [markdown]
# ## Desafio do dia: Cálculo de Bônus com Entrada do Usuário
#
# Escreva um programa em Python que solicita ao usuário para digitar seu nome, o valor do seu salário mensal e o valor do bônus que recebeu. O programa deve, então, imprimir uma mensagem saudando o usuário pelo nome e informando o valor do salário em comparação com o bônus recebido.
#
# Regra -> kpi = 1000 + salario * bônus
# # Retorno esperado
#
# Entrada: Luciano, 10000, 1.5
# Output: 16000

# %%
nome = str(input("Digite seu nome: "))
salario = float(input("Digite seu salario, sendo . o caractere separador"))
bonus = float(input("Digite o seu multiplicador de bônus, sendo . o caractere separador: "))

kpi = 1000 + salario*bonus
print(f"Parabéns {nome}, seu bônus foi de {kpi} que é {kpi/salario} vezes maior que seu salário mensal")
# Out:
# Parabéns Luciano, seu bônus foi de 16000.0 que é 1.6 vezes maior que seu salário mensal

# %% [markdown]
# O desafio propôs colocar esse arquivo em uma pequena documentação e escrever um readme de como executar.

# %%
# %%writefile kpi.py

"""Esse arquivo recebe
nome
salario (separado pelo caractere .)
bônus (separado pelo caractere .)

Esse arquivo vai com o retorno de qual é o kpi de bônus e quantas vezes
o kpi é maior que o salário mensal"""

nome = str(input("Digite seu nome: "))
salario = float(input("Digite seu salario, sendo . o caractere separador"))
bonus = float(input("Digite o seu multiplicador de bônus, sendo . o caractere separador: "))

kpi = 1000 + salario*bonus
print(f"Parabéns {nome}, seu bônus foi de {kpi} que é {kpi/salario} vezes maior que seu salário mensal")
# Out:
# Writing kpi.py

# %%
# %%writefile readme.md
#
# Esse arquivo kpi.py recebe as entradas de teclado:
# nome
# salario (separado pelo caractere .)
# bônus (separado pelo caractere .)
#
# Esse arquivo vai com o retorno de qual é o kpi de bônus e quantas vezes
# o kpi é maior que o salário mensal
#
# ***Para executar basta***
# ```bash
# python kpi.py
# ```
# Out:
# Writing readme.md

# %%
# %%writefile desafio.kpi
#
# nome = str(input("Digite seu nome: "))
# if nome.isdigit():
#     print("Você digitou um número em vez de um nome!")
#     exit()
#
# elif len(nome) == 0:
#       print("Você não digitou o nome")
#       exit()
# elif len(nome.isspace()):
#       print("Você digitou apenas o espaço")
# else:
#         pass
#
# salario = float(input("Digite seu salario, sendo . o caractere separador"))
# bonus = float(input("Digite o seu multiplicador de bônus, sendo . o caractere separador: "))
#
# kpi = 1000 + salario*bonus
# print(f"Parabéns {nome}, seu bônus foi de {kpi} que é {kpi/salario} vezes maior que seu salário mensal")
# Out:
# Writing desafio.kpi

# %% [markdown]
# Saindo dos tipos de dados primitivos vamos ao tratamento de erros

# %%
# Exemplo que causa TypeError
try:
    resultado = len(5)
except TypeError as e:
    print(e)  # Imprime a mensagem de erro
# Out:
# object of type 'int' has no len()

# %%
numero = 10
# isinstance serve para chegar o tipo de dado
if isinstance(numero, int):
    print("A variável é um inteiro.")
else:
    print("A variável não é um inteiro.")
# Out:
# A variável é um inteiro.

# %%
# bem bom para chegar outras estruturas de dados
isinstance([5,3,6],list)
# Out:
# True

# %% [markdown]
# ### Exercícios de try-except
#
# Aqui estão cinco exercícios que envolvem TypeError, verificação de tipo (type check), o uso de try-except para tratamento de exceções e a utilização da estrutura condicional if. Esses exercícios aumentam progressivamente em dificuldade e abordam situações práticas onde você pode aplicar esses conceitos.
#
# ***Exercício 21: Conversor de Temperatura***
#
# Escreva um programa que converta a temperatura de Celsius para Fahrenheit. O programa deve solicitar ao usuário a temperatura em Celsius e, utilizando try-except, garantir que a entrada seja numérica, tratando qualquer ValueError. Imprima o resultado em Fahrenheit ou uma mensagem de erro se a entrada não for válida.
#
# ***Exercício 22: Verificador de Palíndromo***
#
# Crie um programa que verifica se uma palavra ou frase é um palíndromo (lê-se igualmente de trás para frente, desconsiderando espaços e pontuações). Utilize try-except para garantir que a entrada seja uma string. Dica: Utilize a função isinstance() para verificar o tipo da entrada.
#
# ***Exercício 23: Calculadora Simples***
#
# Desenvolva uma calculadora simples que aceite duas entradas numéricas e um operador (+, -, *, /) do usuário. Use try-except para lidar com divisões por zero e entradas não numéricas. Utilize if-elif-else para realizar a operação matemática baseada no operador fornecido. Imprima o resultado ou uma mensagem de erro apropriada.
#
# ***Exercício 24: Classificador de Números***
#
# Escreva um programa que solicite ao usuário para digitar um número. Utilize try-except para assegurar que a entrada seja numérica e utilize if-elif-else para classificar o número como "positivo", "negativo" ou "zero". Adicionalmente, identifique se o número é "par" ou "ímpar".
#
# ***Exercício 25: Conversão de Tipo com Validação***
#
# Crie um script que solicite ao usuário uma lista de números separados por vírgula. O programa deve converter a string de entrada em uma lista de números inteiros. Utilize try-except para tratar a conversão de cada número e validar que cada elemento da lista convertida é um inteiro. Se a conversão falhar ou um elemento não for um inteiro, imprima uma mensagem de erro. Se a conversão for bem-sucedida para todos os elementos, imprima a lista de inteiros.

# %%
# exercicio 21

try:
    celsius = int(input("Entre com a tempera em graus Celsius:"))
    fahrenheit = (9.0/5.0)*celsius + 32
    print(f"A temperatura eh {fahrenheit} F")
except ValueError:
    print("Valor de temperatura inválido")
# Out:
# A temperatura eh 35.6 F

# %%
# exercicio 22
palavra = input("Digite uma palavra:")

# por padrão toda entrada em python é um str, por isso vamos tentar uma type convertion e se aceitar a operação
try:
    int(palavra)
    print(r"Tipo não é uma string, entrada inválida \n Encerrando o programa")
    exit()

except:
    # verifica se é uma string, sempre vai ser nesse caso. rs
    #if isinstance(palavra,str):
    #verifica se é palíndronmo

    #deixar todas as letras minúsculas para comparar
    palavra = palavra.lower()
    if palavra == palavra[::-1]:
        print(f"A palavra {palavra} é um palíndromo")
    else:
        print(f"A palavra {palavra} não é um palíndromo")
#    else:
#        print(r"Tipo não é uma string, entrada inválida \n Encerrando o programa")
#        exit()
# Out:
# A palavra ana é um palíndromo

# %%
## Exercicio 23

num1 = float(input("Entre com um número"))
op = input("Entre com a operação matemática")
num2 = float(input("Entre com outro número"))

## verificar se o operador está na lista de possibilidades
if op in ('-','+','/','*'):
    pass
else:
    print("Operação matemática errada, abortar programa.")
    exit()

# faz a calculadora basica e retorna o valor, tratando a exceção da divisão por zero
if op == '-':
    print(f"Resultado {num1} {op} {num2} = {num1 - num2}")
elif op == '+':
    print(f"Resultado {num1} {op} {num2} = {num1 + num2}")
elif op == '*':
        print(f"Resultado {num1} {op} {num2} = {num1 * num2}")
else:
    try:
        print(f"Resultado {num1} {op} {num2} = {num1/num2}")
    except ZeroDivisionError:
        print("Impossível realizar divisão por zero")
# Out:
# Operação válida
# Impossível reaiizar divisão por zero

# %%
## exercício 24
try:
    numero = float(input("Entre com o valor numérico"))
    if numero <0:
        print(f"O número {numero} é negativo")
    elif numero >0:
        print(f"O número {numero} é positivo")
    else:
        print(f"O número {numero} é zero")
    
    if numero // 2 == 0:
        print(f"O número {numero} é par")
    else:
        print(f"O número {numero} é ímpar")
except:
    print("Não foi inserido um valor numérico, encerrar o programa.")
# Out:
# Não foi inserido um valor numérico, encerrar o programa.

# %%
# exercicio 25

# ahh bons tempos, usava tanta essa entrada em um linha só, com essa função map lindona
# em etapas, a entrada é separada em vírgulas, interage item a item com a função int, devido a função map, depois o map é convertido em uma lista
try:
    lista_numerica = list(map(int,input("Digite a lista de valores:").split(',')))
    print(lista_numerica)
except:
    print("Entrada incorreta, abortar programa")
# Out:
# [1, 2, 3, 4, 5]
